# %% [markdown]
# <a href="https://colab.research.google.com/github/AyandaMnyango/Machine_learning/blob/main/Week_4_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=30)

model = LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
accuracy = accuracy_score(y_test, y_predict)
conf_matrix = confusion_matrix(y_test, y_predict)

print(f"The accuracy {accuracy:.2f}")
print(f"The confusion matrix {conf_matrix}")

ConfusionMatrixDisplay.from_predictions(y_test, y_predict)
plt.title("The confusion matrix")
plt.show()model = LogisticRegression()
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
accuracy = accuracy_score(y_test, y_predict)

from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardClassifier
from sklearn.metrics import accuracy_score

X, y = load_wine(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.2, random_state=30)

# Without scaling
model = KNeighborsClassifier(n_neighbors= 8)
model.fit(X_train, y_train)
y_predict = model.predict(X_test)
accuracy = accuracy_score(y_test, y_predict)

#knn with scaling
scaler = StandardScaler()
X_train_data = scaler.fit_transform(X_train)
X_test_data = scaler.tranform(X_test)

model_scaled = KNeighborsClassifier(n_neighbors=8)
model.scaled.fit(X_train_data, y_train)
y_scaled_predict = model_scaled.predict(X_test)
accuracy_scaled = accuracy_score(y_test, y_predict)

print(f"Accuracy  without scaling {accuracy:.2f}")
print(f"Accuracy  with scaling {accuracy_scaled:.2f}")

#Train KNN on Iris | k
#Which k gives the best accuracy
# Out:
# The accuracy 0.97
# The confusion matrix [[39  0  0]
#  [ 0 39  2]
#  [ 0  1 39]]
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_5382/1085269317.py in <cell line: 0>()
#      29 from sklearn.model_selection import train_test_split
#      30 from sklearn.neighbors import KNeighborsClassifier
# ---> 31 from sklearn.preprocessing import StandardClassifier
#      32 from sklearn.metrics import accuracy_score
#      33
#
# ImportError: cannot import name 'StandardClassifier' from 'sklearn.preprocessing' (/usr/local/lib/python3.12/dist-packages/sklearn/preprocessing/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...
